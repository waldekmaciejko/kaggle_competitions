# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data_all = pd.read_csv('pima_indians_diabetes_all.csv')
data_all.sample(10)
# Out:
#      preg_count  glucose_concentration  diastolic_bp  \
# 719           5                     97            76
# 58            0                    146            82
# 383           1                     90            62
# 162           0                    114            80
# 517           7                    125            86
# 137           0                     93            60
# 453           2                    119             0
# 143          10                    108            66
# 411           1                    112            72
# 283           7                    161            86
#
#      triceps_skin_fold_thickness  two_hr_serum_insulin   bmi  diabetes_pedi  \
# 719                           27                     0  35.6          0.378
# 58                             0                     0  40.5          1.781
# 383                           18                    59  25.1          1.268
# ...

# %%
# zero values are inapropriate so to improve data quality, 
# zero values will be convert to mean values

# %%
#data_all.groupby(by='diabetes_class')['diabetes_class'].count()
data_all['diabetes_class'].value_counts()
# Out:
# 0    500
# 1    268
# Name: diabetes_class, dtype: int64

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   preg_count                   768 non-null    int64
#  1   glucose_concentration        768 non-null    int64
#  2   diastolic_bp                 768 non-null    int64
#  3   triceps_skin_fold_thickness  768 non-null    int64
#  4   two_hr_serum_insulin         768 non-null    int64
#  5   bmi                          768 non-null    float64
#  6   diabetes_pedi                768 non-null    float64
#  7   age                          768 non-null    int64
#  8   diabetes_class               768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data_all.describe()
# Out:
#        preg_count  glucose_concentration  diastolic_bp  \
# count  768.000000             768.000000    768.000000
# mean     3.845052             120.894531     69.105469
# std      3.369578              31.972618     19.355807
# min      0.000000               0.000000      0.000000
# 25%      1.000000              99.000000     62.000000
# 50%      3.000000             117.000000     72.000000
# 75%      6.000000             140.250000     80.000000
# max     17.000000             199.000000    122.000000
#
#        triceps_skin_fold_thickness  two_hr_serum_insulin         bmi  \
# count                   768.000000            768.000000  768.000000
# mean                     20.536458             79.799479   31.992578
# std                      15.952218            115.244002    7.884160
# min                       0.000000              0.000000    0.000000
# 25%                       0.000000              0.000000   27.300000
# ...

# %%
sns.pairplot(data_all.iloc[:, :-1])
